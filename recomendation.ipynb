# %%
import pandas as pd

# %%
s=pd.read_csv("sies.csv",encoding="ISO-8859-1")

# %%
s.head()
# Out:
#                                    title   \
# 0  Tips and Tricks for Python Programmers
# 1                          SRM01 - Report
# 2        Issue Tracking for SIESGSTarena"
# 3                  Single Round Match #02
# 4                           What is arena
#
#                                             content   upvote  downvote   \
# 0    explanation oh how to learn python learn python       8          0
# 1   Congratulations Participants! You did a great...       1          0
# 2  , SIESGSTarena's developer team has adopted Co...       1          0
# 3  eetings to everyone and welcome to the Codeche...       0          0
# 4  to run regular contests according to new and i...       6          0
#
#         tags
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  srm01,srm

# %%
s
# Out:
#                                                title   \
# 0              Tips and Tricks for Python Programmers
# 1                                      SRM01 - Report
# 2                    Issue Tracking for SIESGSTarena"
# 3                              Single Round Match #02
# 4                                       What is arena
# 5                Tips and Tricks for Java Programmers
# 6                              Single Round Match #01
# 7                              Single Round Match #03
# 8                         The Chat Pattern Editorial"
# 9       Learn to code, drink coffee, change the world
# 10                      Plagiarism & Art of Upsolving
# 11                    Don't You Worry Child Editorial
# 12                            Single Round Match #07
# 13                             Single Round Match #04
# 14                                     AUG18 - Report
# 15                                     SRM09 - Report
# 16                                     BETA Round #01
# 17                       Feature Set (Latest Updated)
# 18                  Invitation to the Turing Cup 2019
# 19                                       SRM03-Report
# 20                Tips and Tricks for C++ Programmers
# 21                                    SEPT18 - Report
# 22                             single Round Match #06
# 23                             Single Round Match #07
# 24      Want to become a Problem Setter / Developer ?
# 25                                  August Queue 2018
# 26                               September Queue 2018
# 27         Announcing SIESGSTarena's Open Source Site
# 28  Introducing Codechef Certified Candidates Dash...
# 29                           Google I/O 2019 Updates!
# 30                     Now what happened during SRM03
# 31                                     SRM02 - Report
# 32                Tragedy of SRM02 (It'll be unrated)
# 33                             Single Round Match #08
# 34  Has anyone used \"Jump to Definition\" on GitHub?
# 35                                    SRM #X - Report
# 36                                      SRM-04 Report
# 37         How to create your own testcase generator?
# 38                         Team SIESGSTarena 2019-20"
# 39                            Beta Round #01 - Report
# 40                    Single Round Match 05 -- Report
# 41                              Single Round Match #0
# 42                               So much to remember!
# 43  Here's What No One Tells You About Competitive...
# 44                                            Coding?
# 45                               My CCDSAP Experience
# 46                      Swedish House Mafia Editorial
# 47                                         byte camp
# 48                                     srm 08 report
# 49                                 single round match
# 50                                    SRM #X - Report
# 51                               single round match 5
# 52                        FEs! Introducing Playlists!
# 53                      Maximum sum sub-array problem
# 54                                            SRM #XI
# 55                                   SRM #11 - Report
#
#                                              content   upvote  downvote   \
# 0     explanation oh how to learn python learn python       8          0
# 1    Congratulations Participants! You did a great...       1          0
# 2   , SIESGSTarena's developer team has adopted Co...       1          0
# 3   eetings to everyone and welcome to the Codeche...       0          0
# 4   to run regular contests according to new and i...       6          0
# 5   practice is the only way that ensures increase...      10          0
# 6   Single Round Match #01The contest will start o...       0          0
# 7   will be Cognition. The problems will be based ...       2          0
# 8   middle characters (mid/2 and mid/2+1 indexed c...       5          0
# 9   starting, or being too late, is the most commo...      14          0
# 10  ring the first August Queue this month, me and...       1          0
# 11  Link to the problem. This problem is known as ...       1          0
# 12  ations to all participants of SRM07.We are hap...       4          0
# 13  The contest will commence on 29 September (Sat...       7          0
# 14   Congratulations Participants! You have succes...       2          0
# 15  ations to all the participants. Thank you for ...       6          0
# 16  greetings to all the codersWelcome to thCodeCh...       5          0
# 17  get a result.But all the solution codes and re...      12          2
# 18  , on behalf of the Codechef Campus Chapter at ...       6          0
# 19  Predict Shambhavi  The naive approach of solvi...       3          0
# 20  dd some power and speed potions to your coding...      11          0
# 21  Congratulations Participants! You did a great ...       5          0
# 22  congratulations participants! Thank you for pa...       4          0
# 23  greeting to everyone and welcome to the sevent...       9          0
# 24  have some tricky and interesting problem ideas...       4          1
# 25  greetings to everyone and welcome to the Codec...       0          0
# 26  eetings to everyone and welcome to the CodeChe...       8          0
# 27  STarena, we focus on improving the level of Co...       5          0
# 28  t was on 13th December 2018 when Codechef intr...       4          0
# 29  know more about Jeff, [read here](https://www....       5          0
# 30  w we are at our 3rd Single Round Match and all...       0          0
# 31  Congratulations Participants! You did a great ...       1          0
# 32  uper tight schedule of BUG4EVER and back to ba...       1          0
# 33  u for being here! I am very excited to announc...       6          0
# 34  ing amazing!   For a subset of public reposito...       2          0
# 35  congratulations to everyone and Vipul Singh Ra...       3          0
# 36  sorted. Print the index of each number, in ord...       6          0
# 37   this one question which always haunted me for...       4          0
# 38  ion for talent hasnt ever been this fierce be...       4          0
# 39  congratulations and a lot of thanks to all the...       5          0
# 40  Congratulations Participants! You have success...       4          0
# 41  s to everyone and welcome to the sixth single ...       7          0
# 42  wonder, how do these programmers and developer...       9          0
# 43  eryone, It's Surya here. This week we will tal...       8          0
# 44  first step is start, start somewhere! Almost e...       7          1
# 45  my second year of Engineering course when I wa...       4          0
# 46  \"http://arena.siesgst.ac.in/contest/GBYE19/pr...       3          0
# 47  19 , SIES GST's very own hackathon is back for...       7          0
# 48  re concluding  SRM08 congratulations to everyo...       6          0
# 49  .The contest will commence on 3rd March (Sunda...       6          0
# 50  etings to all the coders!Welcome to the  CodeC...       7          0
# 51  etings to everyone and welcome and will last f...       7          0
# 52  ellow coders! If you aren't familiar with comp...      10          0
# 53                                            problem       5          0
# 54  h is toughMath is complicatedGreetings to all ...       7          0
# 55                congratulations to our participants       6          0
#
#          tags
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4   srm01,srm
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN

# %%
k=s.drop(["downvote "," tags"],axis=1)

# %%
for col in k.columns: 
    print(col)
# Out:
# title
# content
# upvote

# %%
k
# Out:
#                                                title   \
# 0              Tips and Tricks for Python Programmers
# 1                                      SRM01 - Report
# 2                    Issue Tracking for SIESGSTarena"
# 3                              Single Round Match #02
# 4                                       What is arena
# 5                Tips and Tricks for Java Programmers
# 6                              Single Round Match #01
# 7                              Single Round Match #03
# 8                         The Chat Pattern Editorial"
# 9       Learn to code, drink coffee, change the world
# 10                      Plagiarism & Art of Upsolving
# 11                    Don't You Worry Child Editorial
# 12                            Single Round Match #07
# 13                             Single Round Match #04
# 14                                     AUG18 - Report
# 15                                     SRM09 - Report
# 16                                     BETA Round #01
# 17                       Feature Set (Latest Updated)
# 18                  Invitation to the Turing Cup 2019
# 19                                       SRM03-Report
# 20                Tips and Tricks for C++ Programmers
# 21                                    SEPT18 - Report
# 22                             single Round Match #06
# 23                             Single Round Match #07
# 24      Want to become a Problem Setter / Developer ?
# 25                                  August Queue 2018
# 26                               September Queue 2018
# 27         Announcing SIESGSTarena's Open Source Site
# 28  Introducing Codechef Certified Candidates Dash...
# 29                           Google I/O 2019 Updates!
# 30                     Now what happened during SRM03
# 31                                     SRM02 - Report
# 32                Tragedy of SRM02 (It'll be unrated)
# 33                             Single Round Match #08
# 34  Has anyone used \"Jump to Definition\" on GitHub?
# 35                                    SRM #X - Report
# 36                                      SRM-04 Report
# 37         How to create your own testcase generator?
# 38                         Team SIESGSTarena 2019-20"
# 39                            Beta Round #01 - Report
# 40                    Single Round Match 05 -- Report
# 41                              Single Round Match #0
# 42                               So much to remember!
# 43  Here's What No One Tells You About Competitive...
# 44                                            Coding?
# 45                               My CCDSAP Experience
# 46                      Swedish House Mafia Editorial
# 47                                         byte camp
# 48                                     srm 08 report
# 49                                 single round match
# 50                                    SRM #X - Report
# 51                               single round match 5
# 52                        FEs! Introducing Playlists!
# 53                      Maximum sum sub-array problem
# 54                                            SRM #XI
# 55                                   SRM #11 - Report
#
#                                              content   upvote
# 0     explanation oh how to learn python learn python       8
# 1    Congratulations Participants! You did a great...       1
# 2   , SIESGSTarena's developer team has adopted Co...       1
# 3   eetings to everyone and welcome to the Codeche...       0
# 4   to run regular contests according to new and i...       6
# 5   practice is the only way that ensures increase...      10
# 6   Single Round Match #01The contest will start o...       0
# 7   will be Cognition. The problems will be based ...       2
# 8   middle characters (mid/2 and mid/2+1 indexed c...       5
# 9   starting, or being too late, is the most commo...      14
# 10  ring the first August Queue this month, me and...       1
# 11  Link to the problem. This problem is known as ...       1
# 12  ations to all participants of SRM07.We are hap...       4
# 13  The contest will commence on 29 September (Sat...       7
# 14   Congratulations Participants! You have succes...       2
# 15  ations to all the participants. Thank you for ...       6
# 16  greetings to all the codersWelcome to thCodeCh...       5
# 17  get a result.But all the solution codes and re...      12
# 18  , on behalf of the Codechef Campus Chapter at ...       6
# 19  Predict Shambhavi  The naive approach of solvi...       3
# 20  dd some power and speed potions to your coding...      11
# 21  Congratulations Participants! You did a great ...       5
# 22  congratulations participants! Thank you for pa...       4
# 23  greeting to everyone and welcome to the sevent...       9
# 24  have some tricky and interesting problem ideas...       4
# 25  greetings to everyone and welcome to the Codec...       0
# 26  eetings to everyone and welcome to the CodeChe...       8
# 27  STarena, we focus on improving the level of Co...       5
# 28  t was on 13th December 2018 when Codechef intr...       4
# 29  know more about Jeff, [read here](https://www....       5
# 30  w we are at our 3rd Single Round Match and all...       0
# 31  Congratulations Participants! You did a great ...       1
# 32  uper tight schedule of BUG4EVER and back to ba...       1
# 33  u for being here! I am very excited to announc...       6
# 34  ing amazing!   For a subset of public reposito...       2
# 35  congratulations to everyone and Vipul Singh Ra...       3
# 36  sorted. Print the index of each number, in ord...       6
# 37   this one question which always haunted me for...       4
# 38  ion for talent hasnt ever been this fierce be...       4
# 39  congratulations and a lot of thanks to all the...       5
# 40  Congratulations Participants! You have success...       4
# 41  s to everyone and welcome to the sixth single ...       7
# 42  wonder, how do these programmers and developer...       9
# 43  eryone, It's Surya here. This week we will tal...       8
# 44  first step is start, start somewhere! Almost e...       7
# 45  my second year of Engineering course when I wa...       4
# 46  \"http://arena.siesgst.ac.in/contest/GBYE19/pr...       3
# 47  19 , SIES GST's very own hackathon is back for...       7
# 48  re concluding  SRM08 congratulations to everyo...       6
# 49  .The contest will commence on 3rd March (Sunda...       6
# 50  etings to all the coders!Welcome to the  CodeC...       7
# 51  etings to everyone and welcome and will last f...       7
# 52  ellow coders! If you aren't familiar with comp...      10
# 53                                            problem       5
# 54  h is toughMath is complicatedGreetings to all ...       7
# 55                congratulations to our participants       6

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf=TfidfVectorizer(min_df=3,max_features=None,ngram_range=(1,3),stop_words='english',strip_accents='unicode',analyzer='word',token_pattern=r'\w{1,}')

# %%
v=tf.fit_transform(k["content "])

# %%
v
# Out:
# <56x550 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2895 stored elements in Compressed Sparse Row format>

# %%
v.shape
# Out:
# (56, 550)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

# %%
sig=sigmoid_kernel(v,v)

# %%
sig[0]
# Out:
# array([0.76235669, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76169906, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.7617094 , 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.7617085 ,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.76182164,
#        0.76159416, 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76165355, 0.76159416, 0.76159416,
#        0.76159416])

# %%
ind=pd.Series(k.index,index=k["title "]).drop_duplicates()
ind
# Out:
# title
# Tips and Tricks for Python Programmers                          0
# SRM01 - Report                                                  1
# Issue Tracking for SIESGSTarena"                                2
# Single Round Match #02                                          3
# What is arena                                                   4
# Tips and Tricks for Java Programmers                            5
# Single Round Match #01                                          6
# Single Round Match #03                                          7
#  The Chat Pattern Editorial"                                    8
# Learn to code, drink coffee, change the world                   9
# Plagiarism & Art of Upsolving                                  10
# Don't You Worry Child Editorial                                11
# Single Round Match #07                                         12
# Single Round Match #04                                         13
# AUG18 - Report                                                 14
# SRM09 - Report                                                 15
# BETA Round #01                                                 16
# Feature Set (Latest Updated)                                   17
# Invitation to the Turing Cup 2019                              18
# SRM03-Report                                                   19
# Tips and Tricks for C++ Programmers                            20
# SEPT18 - Report                                                21
# single Round Match #06                                         22
# Single Round Match #07                                         23
# Want to become a Problem Setter / Developer ?                  24
# August Queue 2018                                              25
# September Queue 2018                                           26
# Announcing SIESGSTarena's Open Source Site                     27
# Introducing Codechef Certified Candidates Dashboard            28
# Google I/O 2019 Updates!                                       29
# Now what happened during SRM03                                 30
# SRM02 - Report                                                 31
# Tragedy of SRM02 (It'll be unrated)                            32
# Single Round Match #08                                         33
# Has anyone used \"Jump to Definition\" on GitHub?              34
# SRM #X - Report                                                35
# SRM-04 Report                                                  36
# How to create your own testcase generator?                     37
# Team SIESGSTarena 2019-20"                                     38
# Beta Round #01 - Report                                        39
# Single Round Match 05 -- Report                                40
# Single Round Match #0                                          41
# So much to remember!                                           42
# Here's What No One Tells You About Competitive Programming.    43
# Coding?                                                        44
# My CCDSAP Experience                                           45
# Swedish House Mafia Editorial                                  46
# byte camp                                                      47
# srm 08 report                                                  48
# single round match                                             49
# SRM #X - Report                                                50
# single round match 5                                           51
# FEs! Introducing Playlists!                                    52
# Maximum sum sub-array problem                                  53
# SRM #XI                                                        54
# SRM #11 - Report                                               55
# dtype: int64

# %%
def grec(title,sig=sig):
    idx=ind[title]
    sc=list(enumerate(sig[idx]))
    sc=sorted(sc,key=lambda x:x[1],reverse=True)
    sc=sc[1:5]
    movie=[i[0] for i in sc]
    return k["title "].iloc[movie]

# %%
grec("SRM #11 - Report")
# Out:
# 39            Beta Round #01 - Report
# 22             single Round Match #06
# 40    Single Round Match 05 -- Report
# 31                     SRM02 - Report
# Name: title , dtype: object
